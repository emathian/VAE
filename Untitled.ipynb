# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import pandas as pd
import seaborn as sns
import sklearn 
# import metric
import umap
# Out:
# /home/mathiane/miniconda3/envs/ImgProcess/lib/python3.6/site-packages/umap/__init__.py:9: UserWarning: Tensorflow not installed; ParametricUMAP will be unavailable
#   warn("Tensorflow not installed; ParametricUMAP will be unavailable")

# %%
df_loss = pd.read_csv('front_best_model_vae_Biggest_BN.csv', header = None, sep='\t')

# %%
df_loss.iloc[0,0]
# Out:
# '/home/mathiane/ln_LNEN_work_mathian/Tiles_512_512_1802/TNE0417/accept/TNE0417_51745_28645.jpg'

# %%
loss_values = []
sample = []
for i in range(df_loss.shape[0]):
    sample.append(df_loss.iloc[i,0].split('/')[5])
    loss = df_loss.iloc[i,1]
    loss_value = float(loss.split('[')[1].split(']')[0])
    loss_values.append(loss_value)
    
df_loss['loss_value'] = loss_values
df_loss['sample'] = sample
df_loss.head()
# Out:
#                                                    0  \
# 0  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# 1  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# 2  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# 3  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# 4  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
#
#                                        1  loss_value   sample
# 0  tensor([35321.1680], device='cuda:0')  35321.1680  TNE0417
# 1  tensor([35321.1680], device='cuda:0')  35321.1680  TNE0417
# 2  tensor([45111.5508], device='cuda:0')  45111.5508  TNE0417
# 3  tensor([14214.3750], device='cuda:0')  14214.3750  TNE0417
# 4  tensor([20884.8574], device='cuda:0')  20884.8574  TNE0417

# %%
 sns.displot(data = df_loss , x='loss_value')

# %%
df_loss.index = df_loss['sample']
df_loss.head()
# Out:
#                                                          0  \
# sample
# TNE0417  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE0417  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE0417  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE0417  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE0417  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
#
#                                              1  loss_value   sample
# sample
# TNE0417  tensor([35321.1680], device='cuda:0')  35321.1680  TNE0417
# TNE0417  tensor([35321.1680], device='cuda:0')  35321.1680  TNE0417
# TNE0417  tensor([45111.5508], device='cuda:0')  45111.5508  TNE0417
# TNE0417  tensor([14214.3750], device='cuda:0')  14214.3750  TNE0417
# TNE0417  tensor([20884.8574], device='cuda:0')  20884.8574  TNE0417

# %%
set(df_loss['sample'])
# Out:
# {'TNE0004',
#  'TNE0005',
#  'TNE0006',
#  'TNE0009',
#  'TNE0017',
#  'TNE0019',
#  'TNE0025',
#  'TNE0027',
#  'TNE0028',
#  'TNE0031',
#  'TNE0033',
#  'TNE0060',
#  'TNE0066',
#  'TNE0067',
#  'TNE0069',
#  'TNE0071',
#  'TNE0072',
#  'TNE0073',
#  'TNE0078',
#  'TNE0081',
#  'TNE0180',
#  'TNE0230',
#  'TNE0233',
#  'TNE0235',
#  'TNE0263',
#  'TNE0278',
#  'TNE0287',
#  'TNE0288',
#  'TNE0308',
#  'TNE0340',
#  'TNE0341',
#  'TNE0360',
#  'TNE0387',
#  'TNE0406',
#  'TNE0416',
#  'TNE0417',
#  'TNE0450',
#  'TNE0451',
#  'TNE0452',
#  'TNE0477',
#  'TNE0478',
#  'TNE0479',
#  'TNE0485',
#  'TNE0487',
#  'TNE0493',
#  'TNE0495',
#  'TNE0500',
#  'TNE0503',
#  'TNE0504',
#  'TNE0509',
#  'TNE0514',
#  'TNE0515',
#  'TNE0516',
#  'TNE0520',
#  'TNE0528',
#  'TNE0530',
#  'TNE0531',
#  'TNE0534',
#  'TNE0535',
#  'TNE0543',
#  'TNE0545',
#  'TNE0547',
#  'TNE0553',
#  'TNE0554',
#  'TNE0555',
#  'TNE0561',
#  'TNE0563',
#  'TNE0567',
#  'TNE0574',
#  'TNE0575',
#  'TNE0576',
#  'TNE0591',
#  'TNE0795',
#  'TNE0798',
#  'TNE0805',
#  'TNE0810',
#  'TNE0859',
#  'TNE0860',
#  'TNE0861',
#  'TNE0865',
#  'TNE0866',
#  'TNE0867',
#  'TNE0868',
#  'TNE0869',
#  'TNE0870',
#  'TNE0872',
#  'TNE0876',
#  'TNE0877',
#  'TNE0879',
#  'TNE0881',
#  'TNE0888',
#  'TNE0889',
#  'TNE0891',
#  'TNE0936',
#  'TNE0944',
#  'TNE0950',
#  'TNE0952',
#  'TNE0959',
#  'TNE0961',
#  'TNE0966',
#  'TNE0969',
#  'TNE0972',
#  'TNE0973',
#  'TNE0974',
#  'TNE0979',
#  'TNE0980',
#  'TNE0981',
#  'TNE0985',
#  'TNE0987',
#  'TNE0988',
#  'TNE0997',
#  'TNE0999',
#  'TNE1001',
#  'TNE1003',
#  'TNE1007',
#  'TNE1008',
#  'TNE1010',
#  'TNE1017',
#  'TNE1020',
#  'TNE1023',
#  'TNE1024',
#  'TNE1025',
#  'TNE1026',
#  'TNE1027',
#  'TNE1077',
#  'TNE1082',
#  'TNE1086',
#  'TNE1090',
#  'TNE1092',
#  'TNE1093',
#  'TNE1094',
#  'TNE1095',
#  'TNE1099',
#  'TNE1100',
#  'TNE1338',
#  'TNE1350',
#  'TNE1359',
#  'TNE1367',
#  'TNE1403',
#  'TNE1405',
#  'TNE1406',
#  'TNE1408',
#  'TNE1409',
#  'TNE1412',
#  'TNE1413',
#  'TNE1415',
#  'TNE1419',
#  'TNE1421',
#  'TNE1427',
#  'TNE1428',
#  'TNE1429',
#  'TNE1431',
#  'TNE1434',
#  'TNE1438',
#  'TNE1440',
#  'TNE1442',
#  'TNE1444',
#  'TNE1446',
#  'TNE1448',
#  'TNE1452',
#  'TNE1454',
#  'TNE1499',
#  'TNE2105',
#  'TNE2112',
#  'TNE2117',
#  'TNE2127',
#  'TNE2136',
#  'TNE2141',
#  'TNE2142',
#  'TNE2149',
#  'TNE2150'}

# %%
df_pred_test = df_loss[df_loss['sample'] == 'TNE1023']
df_pred_test.head()
# Out:
#                                                          0  \
# sample
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
#
#                                              1  loss_value   sample
# sample
# TNE1023  tensor([72242.6016], device='cuda:0')  72242.6016  TNE1023
# TNE1023  tensor([72740.2969], device='cuda:0')  72740.2969  TNE1023
# TNE1023  tensor([68761.8750], device='cuda:0')  68761.8750  TNE1023
# TNE1023  tensor([73050.4375], device='cuda:0')  73050.4375  TNE1023
# TNE1023  tensor([66390.9219], device='cuda:0')  66390.9219  TNE1023

# %%
x = []
y = []
sample_test = []
for i in range(df_pred_test.shape[0]):
    filen = df_pred_test.iloc[i,0]
    sample_c = df_pred_test.index[i]
    x_c = int(filen.split('/')[-1].split('_')[1])
    
    try:
        y_c = int(filen.split('/')[-1].split('_')[-1].split('.')[0])
    except:
        if filen.split('/')[-1].split('_')[-1].split('.')[0].find('flip') != -1:
            y_c = int(filen.split('/')[-1].split('_')[-1].split('.')[0].split('flip')[0])
        else:
            y_c = int(filen.split('/')[-1].split('_')[-1].split('.')[0].split('rotated')[0])
    sample_test.append(sample_c)
    x.append(x_c)
    y.append(y_c)
df_pred_test['sample'] = sample_test
df_pred_test['x'] = x
df_pred_test['y'] = y
# Out:
# /home/mathiane/miniconda3/envs/ImgProcess/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mathiane/miniconda3/envs/ImgProcess/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mathiane/miniconda3/envs/ImgProcess/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_pred_test.head()
# Out:
#                                                          0  \
# sample
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
#
#                                              1  loss_value   sample      x  \
# sample
# TNE1023  tensor([72242.6016], device='cuda:0')  72242.6016  TNE1023  18481
# TNE1023  tensor([72740.2969], device='cuda:0')  72740.2969  TNE1023  20329
# TNE1023  tensor([68761.8750], device='cuda:0')  68761.8750  TNE1023  26797
# TNE1023  tensor([73050.4375], device='cuda:0')  73050.4375  TNE1023  17557
# TNE1023  tensor([66390.9219], device='cuda:0')  66390.9219  TNE1023  34189
#
#              y
# sample
# TNE1023   6469
# TNE1023  24025
# TNE1023   6469
# TNE1023  16633
# TNE1023  13861

# %%
sample_maxX_maxY = {}
path_main_TNE = '/data/gcs/lungNENomics/work/MathianE/Tiles_512_512_1802'#args.path_tne_tiles
path_main_NL ='/data/gcs/lungNENomics/work/MathianE/Tiles_512_512_NormalLungHENorm'
outputdir = os.getcwd()
for sample in set(df_pred_test['sample']):
    if sample.find('TNE')!= -1:
        try:
            os.mkdir(os.path.join(outputdir, sample))
        except:
            print('sample_folder created')
        path_main = path_main_TNE
    elif sample.find('NL')!= -1:
        try:
            os.mkdir(os.path.join(outputdir, sample))
        except:
            print('sample_folder created')
        path_main = path_main_NL
    sample_folder = os.path.join(path_main, sample)
    xmax = 0
    ymax = 0
    for folder in os.listdir(sample_folder):
        tiles_p = os.path.join(path_main, sample, folder)
        for tiles_l in os.listdir(tiles_p):
            xmax_c = int(tiles_l.split('_')[1])
            ymax_c  = int(tiles_l.split('_')[2].split('.')[0])
            if xmax < xmax_c:
                xmax = xmax_c
            else:
                xmax = xmax
            if ymax < ymax_c:
                ymax = ymax_c
            else:
                ymax = ymax

    sample_maxX_maxY[sample] = [xmax, ymax]

# %%
sample_maxX_maxY
# Out:
# {'TNE1023': [36961, 36961]}

# %%
full_LNEN_WSI = '/data/gcs/lungNENomics/work/MathianE/FullSlidesToJpegHENormHighQuality/'
for k in sample_maxX_maxY.keys():
    if k in list(df_pred_test['sample']):
        w =  tuple(sample_maxX_maxY[k])[0] + 924
        h = tuple(sample_maxX_maxY[k])[1] + 924
        seq = 924
        W = len(list(range(1, w, seq)))
        H = len(list(range(1, h, seq)))
        mat_prob_atypical =   np.zeros((W*10, H*10)) -1
        mat_prob_norm_atypical =   np.zeros((W*10, H*10)) -1
        df_test_pred_s = df_pred_test[df_pred_test['sample'] == k]
        min_p = df_test_pred_s['loss_value'].min()
        max_p =  df_test_pred_s['loss_value'].max()
        df_test_pred_s['prob_norm'] =  df_test_pred_s['loss_value'] - min_p / (max_p - min_p)
        #print(df_test_pred_s.head())
        for i in range(df_test_pred_s.shape[0]):
            x_ = df_test_pred_s.iloc[i,:]['x']
            y_ = df_test_pred_s.iloc[i,:]['y']
            mat_prob_atypical[x_ // 924 * 10 :x_ // 924 *10 + 10 ,  y_ // 924 * 10 :y_ // 924 * 10 + 10 ]= df_test_pred_s.iloc[i,2]
            mat_prob_norm_atypical[x_ // 924 * 10 :x_ // 924 *10 + 10 ,  y_ // 924 * 10 :y_ // 924 * 10 + 10 ]= df_test_pred_s.iloc[i,6]


        try:
            # Full WSI
            if k.find('TNE') != -1:
                get_full_img = full_LNEN_WSI + k + '.jpg'
                print('get_full_img  ', get_full_img)
            elif k.find('NL') != -1:
                get_full_img = full_NL_WSI + k + '.jpg'
                print('get_full_img  ', get_full_img)
            im = cv2.imread(get_full_img)
            fig=plt.figure(1,figsize=(15,15))
            plt.imshow(im.astype('uint8'))
            types =  list(df_pred_test[df_pred_test['sample'] == k].iloc[:,1])[0]
            if types == 1:
                typesN = 'Normal'
            elif types == 0:
                typesN = 'Tumoral'
            else:
                typesN = 'Normal'
            plt.title('WSI_{}_{}'.format(k,typesN))
            fig.savefig(os.path.join(outputdir, k,'WSI_{}_{}.png'.format(k, typesN)), dpi=fig.dpi)
            plt.close()
        except:
            print('WSI not available')



        try:
            # ATypical
            color_map = plt.cm.get_cmap('coolwarm')
            fig=plt.figure(1,figsize=(15,15))
            plt.matshow(mat_prob_atypical,  cmap=color_map,
                        interpolation='none',  fignum=1)
            mtitle = 'Normal tiles scores sample {} '.format(k)
            plt.title(mtitle)
            plt.colorbar()
            fig.savefig(os.path.join(outputdir, k,'Normality_tiles_map_{}.png'.format(k)), dpi=fig.dpi)
            plt.colorbar()
            plt.close()
        except:
            print('Fail atypucal map')

        try:
            # ATypical NORM
            color_map = plt.cm.get_cmap('coolwarm')
            fig=plt.figure(1,figsize=(15,15))
            plt.matshow(mat_prob_norm_atypical,  cmap=color_map,
                        interpolation='none',  fignum=1)
            mtitle = 'Normal tiles scores sample {} '.format(k)
            plt.title(mtitle)
            plt.colorbar()
            fig.savefig(os.path.join(outputdir, k,'Normality_tiles_map_norm_{}.png'.format(k)), dpi=fig.dpi)
            plt.colorbar()
            plt.close()
        except:
            print('Atypical map norm fail')
# Out:
# get_full_img   /data/gcs/lungNENomics/work/MathianE/FullSlidesToJpegHENormHighQuality/TNE1023.jpg

# %%
im1 = cv2.imread('Normality_tiles_map_TNE0066.png')
print(im1)
# Out:
# None

# %%
im1

# %%
df_pred_test = df_loss[df_loss['sample'] == 'TNE1023']
df_pred_test.head()
# Out:
#                                                          0  \
# sample
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
#
#                                              1  loss_value   sample
# sample
# TNE1023  tensor([72242.6016], device='cuda:0')  72242.6016  TNE1023
# TNE1023  tensor([72740.2969], device='cuda:0')  72740.2969  TNE1023
# TNE1023  tensor([68761.8750], device='cuda:0')  68761.8750  TNE1023
# TNE1023  tensor([73050.4375], device='cuda:0')  73050.4375  TNE1023
# TNE1023  tensor([66390.9219], device='cuda:0')  66390.9219  TNE1023

# %%
Best_Normal = df_pred_test.sort_values(by=['loss_value']).iloc[:50, :]

# %%
import shutil
for i in range(Best_Normal.shape[0]):
    try:
        os.mkdir(Best_Normal['sample'][i])
    except:
        print('sample dir already exist')
    try:
        os.mkdir(os.path.join(Best_Normal['sample'][i], 'BestNormal'))
    except:
        print('Best Normal folder already created')
    shutil.copy(Best_Normal.iloc[i,0], os.path.join(Best_Normal['sample'][i], 'BestNormal'))
# Out:
# sample dir already exist
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created

# %%
Best_Normal['sample'][0]
# Out:
# 'TNE1023'

# %%
Best_Tumoral = df_pred_test.sort_values(by=['loss_value'], ascending = False).iloc[:50, :]
Best_Tumoral.head()
# Out:
#                                                          0  \
# sample
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
# TNE1023  /home/mathiane/ln_LNEN_work_mathian/Tiles_512_...
#
#                                               1   loss_value   sample
# sample
# TNE1023  tensor([117345.3281], device='cuda:0')  117345.3281  TNE1023
# TNE1023  tensor([113892.4062], device='cuda:0')  113892.4062  TNE1023
# TNE1023  tensor([113720.0312], device='cuda:0')  113720.0312  TNE1023
# TNE1023  tensor([112276.1875], device='cuda:0')  112276.1875  TNE1023
# TNE1023  tensor([110416.2969], device='cuda:0')  110416.2969  TNE1023

# %%
import shutil
for i in range(Best_Tumoral.shape[0]):
    try:
        os.mkdir(Best_Tumoral['sample'][i])
    except:
        print('sample dir already exist')
    try:
        os.mkdir(os.path.join(Best_Tumoral['sample'][i], 'BestTumoral'))
    except:
        print('Best Normal folder already created')
    shutil.copy(Best_Tumoral.iloc[i,0], os.path.join(Best_Tumoral['sample'][i], 'BestTumoral'))
# Out:
# sample dir already exist
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created
# sample dir already exist
# Best Normal folder already created

# %%
df_vectors = pd.read_csv('Vectors2.csv', header =None, sep= '\t')

# %%
df_vectors.iloc[0,1]
# Out:
# '[0.7631439  0.7643467  0.7631003  ... 0.7219883  0.72321254 0.7216704 ]'
